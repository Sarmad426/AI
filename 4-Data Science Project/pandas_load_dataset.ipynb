# %% [markdown]
# ## Data Classification using Scikit Learn
#
# **Agenda:**
#
# 1. Data Visualization
# 2. Data Preprocessing
# 3. Model filtering using Scikit learn
# 4. Model Evaluation
# 5. Result Analysis

# %% [markdown]
# ## Loading a dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('./vgchartz-2024.csv')

# %%
df.shape
# Out:
# (5677, 14)

# %%
df.describe()
# Out:
#        critic_score  total_sales     na_sales     jp_sales    pal_sales  \
# count   2181.000000  5677.000000  5189.000000  2139.000000  5096.000000
# mean       7.493443     0.971603     0.540225     0.200524     0.334460
# std        1.260504     1.267563     0.680703     0.260980     0.574155
# min        1.700000     0.270000     0.000000     0.000000     0.000000
# 25%        6.800000     0.390000     0.210000     0.020000     0.090000
# 50%        7.700000     0.580000     0.340000     0.100000     0.180000
# 75%        8.400000     1.040000     0.590000     0.300000     0.370000
# max       10.000000    20.320000     9.760000     2.130000     9.850000
#
#        other_sales
# count  5409.000000
# mean      0.107266
# std       0.195569
# min       0.000000
# 25%       0.030000
# 50%       0.050000
# 75%       0.110000
# max       3.120000

# %% [markdown]
# ## Visualizing data using matplotlib histogram

# %%
figure, axis = plt.subplots()
axis.hist(df.describe(), bins=20)

figure
